# %% [markdown]
# ## PS4

# %%
import scipy.stats as sts
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
# Set parameters 
rho = 0.85
mu= 11.4
sigma = 0.7
T = 500

# %% [markdown]
# ### a.

# %%
unif_vec = sts.uniform.rvs(loc=0, scale=1, size=T,
random_state=25)
eps_vec = sts.norm.ppf(unif_vec, loc=0, scale=sigma)

# %%
# Simulation
z = [mu]
for i in range(0,T):
    z.append(rho * z[i] + (1-rho) * mu + eps_vec[i])

# %%
plt.plot(z[:100])
plt.title("First 100 Oberservations")
plt.ylabel("$z_t$")
plt.xlabel("Period t")
plt.show()

# %% [markdown]
# #### b.

# %%
lb = mu - 3*sigma
ub = mu + 3*sigma
z_vals = np.linspace(lb, ub, 5)
z_vals
# Out:
# array([ 9.3 , 10.35, 11.4 , 12.45, 13.5 ])

# %% [markdown]
# #### c.

# %%
z_cuts = 0.5 * z_vals[:-1] + 0.5 * z_vals[1:]
bins = np.digitize(z, z_cuts)

# %%
P_hat = np.zeros(shape=(5,5))
for i in range(0,5):
    for j in range(0,5):
        count = 0
        total = 0
        for k in range(0,T-1):
            curr = bins[k]
            nxt = bins[k + 1]
            if curr == i and nxt == j:
                count += 1
            if curr == i:
                total += 1
        P_hat[i][j] = count/total
P_hat
# Out:
# array([[0.6875    , 0.27083333, 0.04166667, 0.        , 0.        ],
#        [0.09166667, 0.55      , 0.325     , 0.03333333, 0.        ],
#        [0.0304878 , 0.2195122 , 0.48170732, 0.23170732, 0.03658537],
#        [0.        , 0.04201681, 0.34453782, 0.50420168, 0.1092437 ],
#        [0.        , 0.        , 0.04166667, 0.35416667, 0.60416667]])

# %% [markdown]
# #### d.

# %%
import numpy.linalg as LA
zt = np.array([0,0,1,0,0])
cond_prob = LA.matrix_power(P_hat.T, 3) @ zt
print(r'P(z_{t+3}=5|z_t=3)=', cond_prob[4])
# Out:
# P(z_{t+3}=5|z_t=3)= 0.0805878481419583

# %% [markdown]
# #### e.

# %%
eigvals, eigvecmat = LA.eig(P_hat.T)
print(eigvals)
# Out:
# [1.         0.76491631 0.57250397 0.1201336  0.37002179]

# %%
print(eigvecmat)
# Out:
# [[-0.20997214 -0.54371083  0.47281811 -0.01662189 -0.17586139]
#  [-0.49510791 -0.48825994 -0.38117627  0.36522056  0.68671383]
#  [-0.66358995  0.08741449 -0.63733836 -0.78876947 -0.23342473]
#  [-0.48230742  0.55052836  0.07784165  0.49147553 -0.58845084]
#  [-0.19444226  0.39402791  0.46785487 -0.05130473  0.31102314]]

# %%
eigvec = eigvecmat[:, 0] / eigvecmat[:, 0].sum()
stat_dist = eigvec
stat_dist
# Out:
# array([0.10265479, 0.24205688, 0.32442728, 0.23579876, 0.09506228])

# %% [markdown]
# The above is the stationary ergodic distribution of $z_t$ whose eigenvector has the eigenvalue equal to $\lambda = 1$.

# %% [markdown]
# #### f.

# %%
z_0 = z_vals[2]

# %%
x_vec = np.zeros(T)
x_t = z_0
xt_ind = 1
for t_ind in range(T):
    xtp1_ind = \
        np.argwhere(unif_vec[t_ind] <= np.cumsum(P_hat[xt_ind, :])).min()
    x_tp1 = z_vals[xtp1_ind]
    x_vec[t_ind] = x_tp1
    
    x_t = x_tp1
    xt_ind = xtp1_ind

# %%
plt.figure(figsize=(8,6))
plt.plot(x_vec)
plt.plot(z)
plt.grid(b=True, which='major', color='0.65', linestyle=':')
plt.title(r'Discretized vs. Continuous Time Series', fontsize=20)
plt.xlabel(r'Period $t$')
plt.ylabel(r'$Z_t$')
plt.legend(['Discretized', 'Continuous'])
plt.show()
